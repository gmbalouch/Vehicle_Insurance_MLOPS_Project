# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://<user_name>:<password>@cluster0.d978cqk.mongodb.net/?appName=Cluster0"

# above, either remove your credentials or delete the mongoDB resource bofore pushing it to github.

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)

# %%
# Load back data from mongodb

df = pd.DataFrame(list(collection.find()))
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Load back data from mongodb
#       2
# ----> 3 df = pd.DataFrame(list(collection.find()))
#       4 df.head(2)
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\synchronous\cursor.py:1166, in Cursor.__next__(self)
#    1165 def __next__(self) -> _DocumentType:
# -> 1166     return self.next()
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\synchronous\cursor.py:1142, in Cursor.next(self)
#    1140 if self._empty:
#    1141     raise StopIteration
# -> 1142 if len(self._data) or self._refresh():
#    1143     return self._data.popleft()
#    1144 else:
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\synchronous\cursor.py:1113, in Cursor._refresh(self)
#    1098     # Exhaust cursors don't send getMore messages.
#    1099     g = self._getmore_class(
#    1100         self._dbname,
#    1101         self._collname,
#    (...)   1111         self._comment,
#    1112     )
# -> 1113     self._send_message(g)
#    1115 return len(self._data)
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\synchronous\cursor.py:985, in Cursor._send_message(self, operation)
#     982     raise InvalidOperation("exhaust cursors do not support auto encryption")
#     984 try:
# --> 985     response = client._run_operation(
#     986         operation, self._unpack_response, address=self._address
#     987     )
#     988 except OperationFailure as exc:
#     989     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#     990         # Don't send killCursors because the cursor is already closed.
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\synchronous\mongo_client.py:1956, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1946     operation.reset()  # Reset op in case of retry.
#    1947     return server.run_operation(
#    1948         conn,
#    1949         operation,
#    (...)   1953         self,
#    1954     )
# -> 1956 return self._retryable_read(
#    1957     _cmd,
#    1958     operation.read_preference,
#    1959     operation.session,  # type: ignore[arg-type]
#    1960     address=address,
#    1961     retryable=isinstance(operation, _Query),
#    1962     operation=operation.name,
#    1963 )
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\synchronous\mongo_client.py:2076, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id, is_run_command, is_aggregate_write)
#    2072 retryable = bool(
#    2073     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2074 )
#    2075 with self._tmp_session(session) as s:
# -> 2076     return self._retry_internal(
#    2077         func,
#    2078         s,
#    2079         None,
#    2080         operation,
#    2081         is_read=True,
#    2082         address=address,
#    2083         read_pref=read_pref,
#    2084         retryable=retryable,
#    2085         operation_id=operation_id,
#    2086         is_run_command=is_run_command,
#    2087         is_aggregate_write=is_aggregate_write,
#    2088     )
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\synchronous\mongo_client.py:2038, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id, is_run_command, is_aggregate_write)
#    1995 @_csot.apply
#    1996 def _retry_internal(
#    1997     self,
#    (...)   2008     is_aggregate_write: bool = False,
#    2009 ) -> T:
#    2010     """Internal retryable helper for all client transactions.
#    2011
#    2012     :param func: Callback function we want to retry
#    (...)   2023     :return: Output of the calling func()
#    2024     """
#    2025     return _ClientConnectionRetryable(
#    2026         mongo_client=self,
#    2027         func=func,
#    2028         bulk=bulk,
#    2029         operation=operation,
#    2030         is_read=is_read,
#    2031         session=session,
#    2032         read_pref=read_pref,
#    2033         address=address,
#    2034         retryable=retryable,
#    2035         operation_id=operation_id,
#    2036         is_run_command=is_run_command,
#    2037         is_aggregate_write=is_aggregate_write,
# -> 2038     ).run()
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\synchronous\mongo_client.py:2811, in _ClientConnectionRetryable.run(self)
#    2809 self._check_last_error(check_csot=True)
#    2810 try:
# -> 2811     res = self._read() if self._is_read else self._write()
#    2812     # Track whether the transaction has completed a command.
#    2813     # If we need to apply backpressure to the first command,
#    2814     # we will need to revert back to starting state.
#    2815     if self._session is not None and self._session.in_transaction:
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\synchronous\mongo_client.py:3043, in _ClientConnectionRetryable._read(self)
#    3035 if self._retrying:
#    3036     _debug_log(
#    3037         _COMMAND_LOGGER,
#    3038         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)   3041         operationId=self._operation_id,
#    3042     )
# -> 3043 return self._func(self._session, self._server, conn, read_pref)
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\synchronous\mongo_client.py:1947, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1940 def _cmd(
#    1941     _session: Optional[ClientSession],
#    1942     server: Server,
#    1943     conn: Connection,
#    1944     read_preference: _ServerMode,
#    1945 ) -> Response:
#    1946     operation.reset()  # Reset op in case of retry.
# -> 1947     return server.run_operation(
#    1948         conn,
#    1949         operation,
#    1950         read_preference,
#    1951         self._event_listeners,
#    1952         unpack_res,
#    1953         self,
#    1954     )
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\synchronous\helpers.py:53, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      50 from pymongo.synchronous.pool import Connection
#      52 try:
# ---> 53     return func(*args, **kwargs)
#      54 except OperationFailure as exc:
#      55     if no_reauth:
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\synchronous\server.py:208, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res, client)
#     206 else:
#     207     conn.send_message(data, max_doc_size)
# --> 208     reply = conn.receive_message(request_id)
#     210 # Unpack and check for command errors.
#     211 if use_cmd:
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\synchronous\pool.py:459, in Connection.receive_message(self, request_id)
#     457 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     458 except BaseException as error:
# --> 459     self._raise_connection_failure(error)
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\synchronous\pool.py:456, in Connection.receive_message(self, request_id)
#     451 """Receive a raw BSON message or raise ConnectionFailure.
#     452
#     453 If any exception is raised, the socket is closed.
#     454 """
#     455 try:
# --> 456     return receive_message(self, request_id, self.max_message_size)
#     457 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     458 except BaseException as error:
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\network_layer.py:778, in receive_message(conn, request_id, max_message_size)
#     776     data = decompress(receive_data(conn, length - 25, deadline), compressor_id)
#     777 else:
# --> 778     data = receive_data(conn, length - 16, deadline)
#     780 try:
#     781     unpack_reply = _UNPACK_REPLY[op_code]
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\network_layer.py:353, in receive_data(conn, length, deadline)
#     350             short_timeout = _POLL_TIMEOUT
#     351         conn.set_conn_timeout(short_timeout)
# --> 353     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     354 except BLOCKING_IO_ERRORS:
#     355     if conn.cancel_context.cancelled:
#
# File d:\AI-ML Mastery\MLOPS\YT-MLops-Proj1\vehicle\Lib\site-packages\pymongo\network_layer.py:469, in NetworkingInterface.recv_into(self, buffer)
#     468 def recv_into(self, buffer: bytes | memoryview) -> int:
# --> 469     return self.conn.recv_into(buffer)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
## If you are getting timeout issue

# import certifi
# client = pymongo.MongoClient(CONNECTION_URL, tlsCAFile=certifi.where())
# # TO CREATE THE DATABASE
# data_base = client[DB_NAME]
# collection = data_base[COLLECTION_NAME]
# # TO INSERT DATA INTO THE COLLECTION
# rec = collection.insert_many(data)
